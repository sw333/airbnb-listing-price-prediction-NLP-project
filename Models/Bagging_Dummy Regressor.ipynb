# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
import numpy as np
pathlistings = '/content/gdrive/My Drive/BT4222 project/afterfeatureengineering2.csv'
df_listings = pd.read_csv(pathlistings)
len(df_listings)
# Out:
# 99990

# %%
X = df_listings.drop(columns=['price'])
y = df_listings.price

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
print(X_train.shape)
print(X_test.shape)
# Out:
# (74992, 324)
# (24998, 324)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import BaggingRegressor
from sklearn.dummy import DummyRegressor
from sklearn.model_selection import ParameterGrid

grid = ParameterGrid({"max_samples": [0.5, 1.0],
                  "max_features": [0.5, 1.0],
                  "bootstrap": [True, False],
                  "bootstrap_features": [True, False],
                  "n_estimators":[20,30,40,50,60,70,80,100]})
RMSE = 10000000000000000
para_rmse = None
R2 = 1000000000000000000000
para_r2 = None

  
for params in grid:
    print("------------------CURRENT-------------------------")
    print("Current params:",params)
    bagging = BaggingRegressor(base_estimator=DummyRegressor(),
                      random_state=0,
                      **params).fit(X_train, y_train)
    y_pred_train = bagging.predict(X_train) 
    y_pred_test = bagging.predict(X_test) 
    # RMSE
    rmse_train = mean_squared_error(y_train, y_pred_train, squared=False)
    print("This round training RMSE:",rmse_train)
    rmse_test = mean_squared_error(y_test, y_pred_test, squared=False)
    print("This round testing RMSE:",rmse_test)
    # r2
    r2_train = r2_score(y_train, y_pred_train)
    print("This round training R2:",r2_train)
    r2_test = r2_score(y_test, y_pred_test)
    print("This round testing R2:",r2_test)

    if rmse_test < RMSE:
      RMSE = rmse_test
      para_rmse = params
    print("--------------------RMSE-----------------------")
    print("current lowest RMSE:",RMSE)
    print("current best para:", para_rmse)
  
    if r2_test < R2:
      R2 = r2_test
      para_r2 = params
    print("-------------------R2------------------------")
    print("current lowest R2:",R2)
    print("current best para:", para_r2)
# Out:
# ------------------CURRENT-------------------------
# Current params: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 20}
# This round training RMSE: 260.002019690237
# This round testing RMSE: 231.21893310758034
# This round training R2: -2.4892879486593245e-06
# This round testing R2: -2.9446959607382084e-05
# --------------------RMSE-----------------------
# current lowest RMSE: 231.21893310758034
# current best para: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 20}
# -------------------R2------------------------
# current lowest R2: -2.9446959607382084e-05
# current best para: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 20}
# ------------------CURRENT-------------------------
# Current params: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 30}
# This round training RMSE: 260.0019845031141
# This round testing RMSE: 231.2188097431855
# This round training R2: -2.218619219673812e-06
# This round testing R2: -2.8379849807969038e-05
# --------------------RMSE-----------------------
# current lowest RMSE: 231.2188097431855
# current best para: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 30}
# -------------------R2------------------------
# current lowest R2: -2.9446959607382084e-05
# current best para: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 20}
# ------------------CURRENT-------------------------
# Current params: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 40}
# This round training RMSE: 260.0019693714078
# This round testing RMSE: 231.21875512482137
# This round training R2: -2.102222112831953e-06
# This round testing R2: -2.790739769409356e-05
# --------------------RMSE-----------------------
# current lowest RMSE: 231.21875512482137
# current best para: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 40}
# -------------------R2------------------------
# current lowest R2: -2.9446959607382084e-05
# current best para: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 20}
# ------------------CURRENT-------------------------
# Current params: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 50}
# This round training RMSE: 260.00189260761186
# This round testing RMSE: 231.21845953433757
# This round training R2: -1.5117346929827136e-06
# This round testing R2: -2.5350524279099673e-05
# --------------------RMSE-----------------------
# current lowest RMSE: 231.21845953433757
# current best para: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 50}
# -------------------R2------------------------
# current lowest R2: -2.9446959607382084e-05
# current best para: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 20}
# ------------------CURRENT-------------------------
# Current params: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 60}
# This round training RMSE: 260.0020720450171
# This round testing RMSE: 231.21910863276906
# This round training R2: -2.892014940858445e-06
# This round testing R2: -3.09652645458236e-05
# --------------------RMSE-----------------------
# current lowest RMSE: 231.21845953433757
# current best para: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 50}
# -------------------R2------------------------
# current lowest R2: -3.09652645458236e-05
# current best para: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 60}
# ------------------CURRENT-------------------------
# Current params: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 70}
# This round training RMSE: 260.001975856244
# This round testing RMSE: 231.21877865633266
# This round training R2: -2.1521051951634007e-06
# This round testing R2: -2.8110946659332114e-05
# --------------------RMSE-----------------------
# current lowest RMSE: 231.21845953433757
# current best para: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 50}
# -------------------R2------------------------
# current lowest R2: -3.09652645458236e-05
# current best para: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 60}
# ------------------CURRENT-------------------------
# Current params: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 80}
# This round training RMSE: 260.00188938309867
# This round testing RMSE: 231.2184462904442
# This round training R2: -1.486930888416893e-06
# This round testing R2: -2.523596397319139e-05
# --------------------RMSE-----------------------
# current lowest RMSE: 231
-05
# --------------------RMSE-----------------------
# current lowest RMSE: 231.21622051858702
# current best para: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 30}
# -------------------R2------------------------
# current lowest R2: -3.09652645458236e-05
# current best para: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 60}
# ------------------CURRENT-------------------------
# Current params: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 1.0, 'n_estimators': 100}
# This round training RMSE: 260.001696080894
# This round testing RMSE: 231.2170709809929
# This round training R2: 0.0
# This round testing R2: -1.3339507697329722e-05
# --------------------RMSE-----------------------
# current lowest RMSE: 231.21622051858702
# current best para: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 30}
# -------------------R2------------------------
# current lowest R2: -3.09652645458236e-05
# current best para: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 60}
# ------------------CURRENT-------------------------
# Current params: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 0.5, 'n_estimators': 20}
# This round training RMSE: 260.00171229141824
# This round testing RMSE: 231.21675388229636
# This round training R2: -1.246955303457753e-07
# This round testing R2: -1.0596607203927633e-05
# --------------------RMSE-----------------------
# current lowest RMSE: 231.21622051858702
# current best para: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 30}
# -------------------R2------------------------
# current lowest R2: -3.09652645458236e-05
# current best para: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 60}
# ------------------CURRENT-------------------------
# Current params: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 0.5, 'n_estimators': 30}
# This round training RMSE: 260.0017232338313
# This round testing RMSE: 231.21666752510714
# This round training R2: -2.0886739648950936e-07
# This round testing R2: -9.849619049262515e-06
# --------------------RMSE-----------------------
# current lowest RMSE: 231.21622051858702
# current best para: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 30}
# -------------------R2------------------------
# current lowest R2: -3.09652645458236e-05
# current best para: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 60}
# ------------------CURRENT-------------------------
# Current params: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 0.5, 'n_estimators': 40}
# This round training RMSE: 260.00172603044655
# This round testing RMSE: 231.2166488681301
# This round training R2: -2.3037968333028402e-07
# This round testing R2: -9.688236565219555e-06
# --------------------RMSE-----------------------
# current lowest RMSE: 231.21622051858702
# current best para: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 30}
# -------------------R2------------------------
# current lowest R2: -3.09652645458236e-05
# current best para: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 60}
# ------------------CURRENT-------------------------
# Current params: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 0.5, 'n_estimators': 50}
# This round training RMSE: 260.00170878120775
# This round testing RMSE: 231.2167884530435
# This round training R2: -9.769408593207629e-08
# This round testing R2: -1.0895643631769758e-05
# --------------------RMSE-----------------------
# current lowest RMSE: 231.21622051858702
# current best para: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 30}
# -------------------R2------------------------
# current lowest R2: -3.09652645458236e-05
# current best para: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 60}
# ------------------CURRENT-------------------------
# Current params: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 0.5, 'n_estimators': 60}
# This round training RMSE: 260.0017270677129
# This round testing RMSE: 231.2166422088209
# This round training R2: -2.3835860485377225e-07
# This round testing R2: -9.630633674984068e-06
# --------------------RMSE-----------------------
# current lowest RMSE: 231.21622051858702
# current best para: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 30}
# -------------------R2------------------------
# current lowest R2: -3.09652645458236e-05
# current best para: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 60}
# ------------------CURRENT-------------------------
# Current params: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 0.5, 'n_estimators': 70}
# This round training RMSE: 260.0016999899237
# This round testing RMSE: 231.21691071036534
# This round training R2: -3.0069263079468556e-08
# This round testing R2: -1.1953167932121644e-05
# --------------------RMSE-----------------------
# current lowest RMSE: 231.21622051858702
# current best para: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 30}
# -------------------R2------------------------
# current lowest R2: -3.09652645458236e-05
# current best para: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 60}
# ------------------CURRENT-------------------------
# Current params: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 0.5, 'n_estimators': 80}
# This round training RMSE: 260.0017054591223
# This round testing RMSE: 231.21682647356945
# This round training R2: -7.213974817510405e-08
# This round testing R2: -1.1224520644503855e-05
# --------------------RMSE-----------------------
# current lowest RMSE: 231.21622051858702
# current best para: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 30}
# -------------------R2------------------------
# current lowest R2: -3.09652645458236e-05
# current best para: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 60}
# ------------------CURRENT-------------------------
# Current params: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 0.5, 'n_estimators': 100}
# This round training RMSE: 260.0017040181849
# This round testing RMSE: 231.21684526403524
# This round training R2: -6.105568650660587e-08
# This round testing R2: -1.1387057928136102e-05
# --------------------RMSE-----------------------
# current lowest RMSE: 231.21622051858702
# current best para: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 30}
# -------------------R2------------------------
# current lowest R2: -3.09652645458236e-05
# current best para: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 60}
# ------------------CURRENT-------------------------
# Current params: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 20}
# This round training RMSE: 260.001696080894
# This round testing RMSE: 231.2170709809929
# This round training R2: 0.0
# This round testing R2: -1.3339507697329722e-05
# --------------------RMSE-----------------------
# current lowest RMSE: 231.21622051858702
# current best para: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 30}
# -------------------R2------------------------
# current lowest R2: -3.09652645458236e-05
# current best para: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 60}
# ------------------CURRENT-------------------------
# Current params: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 30}
# This round training RMSE: 260.001696080894
# This round testing RMSE: 231.2170709809929
# This round training R2: 0.0
# This round testing R2: -1.3339507697329722e-05
# --------------------RMSE-----------------------
# current lowest RMSE: 231.21622051858702
# current best para: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 30}
# -------------------R2------------------------
# current lowest R2: -3.09652645458236e-05
# current best para: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 60}
# ------------------CURRENT-------------------------
# Current params: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 40}
# This round training RMSE: 260.001696080894
# This round testing RMSE: 231.2170709809929
# This round training R2: 0.0
# This round testing R2: -1.3339507697329722e-05
# --------------------RMSE-----------------------
# current lowest RMSE: 231.21622051858702
# current best para: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 30}
# -------------------R2------------------------
# current lowest R2: -3.09652645458236e-05
# current best para: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 60}
# ------------------CURRENT-------------------------
# Current params: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 50}
# This round training RMSE: 260.001696080894
# This round testing RMSE: 231.2170709809929
# This round training R2: 0.0
# This round testing R2: -1.3339507697329722e-05
# --------------------RMSE-----------------------
# current lowest RMSE: 231.21622051858702
# current best para: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 30}
# -------------------R2------------------------
# current lowest R2: -3.09652645458236e-05
# current best para: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 60}
# ------------------CURRENT-------------------------
# Current params: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 60}
# This round training RMSE: 260.001696080894
# This round testing RMSE: 231.2170709809929
# This round training R2: 0.0
# This round testing R2: -1.3339507697329722e-05
# --------------------RMSE-----------------------
# current lowest RMSE: 231.21622051858702
# current best para: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 30}
# -------------------R2------------------------
# current lowest R2: -3.09652645458236e-05
# current best para: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 60}
# ------------------CURRENT-------------------------
# Current params: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 70}
# This round training RMSE: 260.001696080894
# This round testing RMSE: 231.2170709809929
# This round training R2: 0.0
# This round testing R2: -1.3339507697329722e-05
# --------------------RMSE-----------------------
# current lowest RMSE: 231.21622051858702
# current best para: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 30}
# -------------------R2------------------------
# current lowest R2: -3.09652645458236e-05
# current best para: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 60}
# ------------------CURRENT-------------------------
# Current params: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 80}
# This round training RMSE: 260.001696080894
# This round testing RMSE: 231.2170709809929
# This round training R2: 0.0
# This round testing R2: -1.3339507697329722e-05
# --------------------RMSE-----------------------
# current lowest RMSE: 231.21622051858702
# current best para: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 30}
# -------------------R2------------------------
# current lowest R2: -3.09652645458236e-05
# current best para: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 60}
# ------------------CURRENT-------------------------
# Current params: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 100}
# This round training RMSE: 260.001696080894
# This round testing RMSE: 231.2170709809929
# This round training R2: 0.0
# This round testing R2: -1.3339507697329722e-05
# --------------------RMSE-----------------------
# current lowest RMSE: 231.21622051858702
# current best para: {'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 30}
# -------------------R2------------------------
# current lowest R2: -3.09652645458236e-05
# current best para: {'bootstrap': True, 'bootstrap_features': True, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 60}

# %%
{'bootstrap': False, 'bootstrap_features': False, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 30}
